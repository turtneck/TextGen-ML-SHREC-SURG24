# %%
import torch
import torch.nn as nn
from torch.nn import functional as F
#------------------------
import os,sys
import numpy as np
#sys.path.append('D:/projects/base/app/modules') 
dir_path = os.path.abspath("")
print(f"DIRECTORY:\t\t<{dir_path}>")
sys.path.append(dir_path[:-14])
from fun_colors import *
#------------------------


# hyperparameters
batch_size = 16 # how many independent sequences will we process in parallel?
block_size = 32 # what is the maximum context length for predictions?
max_iters = 10000
eval_interval = 100
learning_rate = 1e-3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 64
n_head = 4
n_layer = 4
dropout = 0.0
# ------------

torch.manual_seed(1337)

BINdir=getDrive()+"book\\gutenburg_BIN\\char_64"
dirlist=os.listdir(BINdir)
print( BINdir+'/'+dirlist[0] )
train_data = np.fromfile(BINdir+'/'+dirlist[0], dtype=np.int64)

train_data_torch = torch.from_numpy(train_data).type(torch.long)
print( 'train_data_torch.dtype', train_data_torch.dtype )
print( 'train_data_torch.type()', train_data_torch.type() )

n = int(0.9*len(train_data_torch)) # first 90% will be train, rest val
train_data = train_data_torch[:n]
val_data = train_data_torch[n:]

# print( dict_arr )
# print( 'train_data', train_data[:200] )

#meta
#meta = { 'vocab_size': len(arr), 'itos': itos, 'stoi': stoi, 'uint': 32 }
with open(getDrive()+"book/gutenburg_BIN\metas\gutenburg_bin-RBT-char_meta_int64.pkl", 'rb') as f: meta = pickle.load(f)

stoi = meta['stoi']
itos = meta['itos']
vocab_size = meta['vocab_size']
# Out:
# DIRECTORY:		<c:\Users\jump3\Desktop\TextGen-ML-SHREC-SURG24\PyTorch-Model>
# D:\book\gutenburg_BIN\char_64/GB_pg1.bin
# train_data_torch.dtype torch.int64
# train_data_torch.type() torch.LongTensor

# %%
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    
    # print("\n\n============================\nDATA======");print(data)
    # print("\n\n============================\nix======");print(ix)
    # print("\n\n============================\npre-x======")
    # t=[data[i:i+block_size] for i in ix]
    # for i in t: print(i.dtype,i)
    
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

# %%
class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

# %%
model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
# ------------------
for iter in range(max_iters):
    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()
# ------------------
# save model
print("\n\n///////////////////////////////////////////////////////////////\nSAVING...\n")
import datetime
dstr=f"{datetime.datetime.now().date()}_{datetime.datetime.now().hour}_{datetime.datetime.now().minute}"
torch.save(model, dir_path+f'/Models/PyTorch_{dstr}_ipynb.pt')
# Out:
# 1.223669 M parameters
# step 0: train loss 9.1996, val loss 9.1548
# step 100: train loss 2.9509, val loss 3.2318
# step 200: train loss 2.6176, val loss 2.9126
# step 300: train loss 2.4923, val loss 2.8215
# step 400: train loss 2.3861, val loss 2.6687
# step 500: train loss 2.2782, val loss 2.5604
# step 600: train loss 2.1942, val loss 2.4795
# step 700: train loss 2.1298, val loss 2.3848
# step 800: train loss 2.0402, val loss 2.3236
# step 900: train loss 1.9936, val loss 2.2225
# step 1000: train loss 1.9437, val loss 2.1729
# step 1100: train loss 1.9144, val loss 2.1488
# step 1200: train loss 1.8657, val loss 2.0791
# step 1300: train loss 1.8172, val loss 2.0677
# step 1400: train loss 1.7938, val loss 2.0671
# step 1500: train loss 1.7587, val loss 2.0240
# step 1600: train loss 1.7307, val loss 1.9924
# step 1700: train loss 1.7177, val loss 1.9624
# step 1800: train loss 1.6849, val loss 1.9960
# step 1900: train loss 1.6601, val loss 1.9343
# step 2000: train loss 1.6504, val loss 1.9605
# step 2100: train loss 1.6226, val loss 1.9482
# step 2200: train loss 1.5973, val loss 1.8873
# step 2300: train loss 1.6056, val loss 1.9327
# step 2400: train loss 1.5640, val loss 1.8919
# step 2500: train loss 1.5638, val loss 1.8985
# step 2600: train loss 1.5342, val loss 1.8849
# step 2700: train loss 1.5319, val loss 1.8698
# step 2800: train loss 1.5220, val loss 1.8908
# step 2900: train loss 1.5123, val loss 1.8834
# step 3000: train loss 1.4961, val loss 1.9014
# step 3100: train loss 1.4783, val loss 1.8765
# step 3200: train loss 1.4819, val loss 1.8517
# step 3300: train loss 1.4567, val loss 1.8908
# step 3400: train loss 1.4533, val loss 1.8677
# step 3500: train loss 1.4424, val loss 1.8668
# step 3600: train loss 1.4384, val loss 1.8461
# step 3700: train loss 1.4293, val loss 1.8829
# step 3800: train loss 1.3957, val loss 1.8665
# step 3900: train loss 1.4192, val loss 1.8774
# step 4000: train loss 1.3905, val loss 1.8704
# step 4100: train loss 1.3924, val loss 1.8675
# step 4200: train loss 1.3752, val loss 1.8656
# step 4300: train loss 1.3776, val loss 1.8355
# step 4400: train loss 1.3706, val loss 1.8579
# step 4500: train loss 1.3609, val loss 1.8524
# step 4600: train loss 1.3681, val loss 1.9055
# step 4700: train loss 1.3414, val loss 1.8898
# step 4800: train loss 1.3432, val loss 1.8795
# step 4900: train loss 1.3323, val loss 1.8589
# step 5000: train loss 1.3316, val loss 1.8751
# step 5100: train loss 1.3295, val loss 1.8865
# step 5200: train loss 1.3164, val loss 1.8452
# step 5300: train loss 1.3151, val loss 1.8752
# step 5400: train loss 1.2944, val loss 1.8576
# step 5500: train loss 1.2997, val loss 1.8780
# step 5600: train loss 1.2893, val loss 1.8695
# step 5700: train loss 1.2838, val loss 1.8563
# step 5800: train loss 1.2645, val loss 1.8850
# step 5900: train loss 1.2786, val loss 1.8903
# step 6000: train loss 1.2723, val loss 1.8436
# step 6100: train loss 1.2578, val loss 1.8731
# step 6200: train loss 1.2659, val loss 1.9042
# step 6300: train loss 1.2580, val loss 1.8760
# step 6400: train loss 1.2493, val loss 1.9051
# step 6500: train loss 1.2370, val loss 1.8848
# step 6600: train loss 1.2342, val loss 1.8662
# step 6700: train loss 1.2355, val loss 1.9089
# step 6800: train loss 1.2255, val loss 1.8848
# step 6900: train loss 1.2144, val loss 1.8804
# step 7000: train loss 1.2241, val loss 1.9241
# step 7100: train loss 1.2105, val loss 1.8767
# step 7200: train loss 1.2088, val loss 1.8429
# step 7300: train loss 1.2016, val loss 1.8695
# step 7400: train loss 1.2008, val loss 1.9038
# step 7500: train loss 1.2015, val loss 1.9215
# step 7600: train loss 1.1868, val loss 1.9132
# step 7700: train loss 1.1835, val loss 1.8744
# step 7800: train loss 1.1921, val loss 1.8880
# step 7900: train loss 1.1766, val loss 1.9093
# step 8000: train loss 1.1725, val loss 1.8831
# step 8100: train loss 1.1714, val loss 1.9279
# step 8200: train loss 1.1754, val loss 1.9437
# step 8300: train loss 1.1725, val loss 1.9475
# step 8400: train loss 1.1712, val loss 1.9448
# step 8500: train loss 1.1557, val loss 1.9640
# step 8600: train loss 1.1519, val loss 1.8917
# step 8700: train loss 1.1476, val loss 1.9722
# step 8800: train loss 1.1538, val loss 1.9435
# step 8900: train loss 1.1459, val loss 1.9428
# step 9000: train loss 1.1390, val loss 1.9358
# step 9100: train loss 1.1423, val loss 1.9804
# step 9200: train loss 1.1366, val loss 1.9597
# step 9300: train loss 1.1310, val loss 1.9886
# step 9400: train loss 1.1405, val loss 1.9492
# step 9500: train loss 1.1158, val loss 1.9257
# step 9600: train loss 1.1179, val loss 1.9623
# step 9700: train loss 1.1181, val loss 1.9546
# step 9800: train loss 1.1115, val loss 2.0000
# step 9900: train loss 1.1169, val loss 1.9421
# step 9999: train loss 1.1111, val loss 1.9681
#
#
# ///////////////////////////////////////////////////////////////
# SAVING...
#
#
#
# ///////////////////////////////////////////////////////////////
# GENERATING...
#
#  to"be obtained by Jurisdiction huld tern
# he hold the there is cope tribune of Votes, of the Constitution, and to not action
# in time them that thin
# this beyof your country press Fover Boston it
# James Qunes. The Jre⟩s enjounts of deptally
# exince. Then indiving Indender usuring meetel esporting them,
# and officially
# unus sups affect. Met unless the
# Officers against tme
# of the United?
# Will Project Guter.
#
# The Rath Dost upon of of these Imports unto fairsures shall not,
# sired by I poild by such, tory or enor provided for corries to
# continue has chule
# sweart; and the
# duty support in or any Confents,
# in the United States that most circumstances shall be convene and orgen which, all over any
# of the United States,
# now to was sent and pierty in any expire purne,
# unto feer it as to only necess of our Project Gutenberg Triberty and
# to raving up", hound to be a Qualifications of two Name
# and pendincing the Seat of the Cessire
# of the Constitution. The prograc
# Place what
# forbid inciancies kept relees poily for of new to and other House of If House.
#
# He has been their rether more than
# the houldwis is tooke
# thouse enlease cost here held the lite me
#
#
# Jacts of the lasture nation of Project
# Gutenberg Lit us toilain, in the in our one Lord.
#
#
# The House, shall not be answered to before of Amendincy cin laust king the Years,
# of the Constitution of the
# several State. We have concile in paragraph 1.
#
# Each immunit. .. .
# with chas so lave including the Lord in every and it it, bother in the Heappendent of Macks of our conse
# the Seat
# no relegated areious with all priotisfrance, where is two the
# may be bound in all the living take to bear the right little to them, and
# unfit itself. We tould in shall be under the same. . .hy shall be require.
# Let usinctions of compire whose. . .
# the loyat continent and ought
# hold to be sept enument uniforne they wishook. It no lower by whostor if the paral laws you.
#
# No vieww or uncourth our a new Declare.
#
#
#
#
#
# "TITR. Without this new mition orbities,
# inched to
#
#
# ///////////////////////////////////////////////////////////////
# LOADING...
#
#
#
# ///////////////////////////////////////////////////////////////
# GENERATING2...
#
#  in when a resultitude of editionally and
# davies obtruction secured by any other hundrey shall ever neat Union,
# mes so compreement nearly Coings of the United States;
# copyright
# rink copy in the lamp inled to the
# Peresident, it become.
#
# If a loort. . .to sast to find the Laws of Nature's Governust in the contined
# in the both of this Number with 1.1.0.
#
# He has fafter years are so inteirst unustiments, and fore inviolence, unless requrence that
# let interrict impunish to be no Journments of that sireou endered,
# and esclected to a clony.
# That it this nature of
# God whether, contain Bribina when Lets of the his, Governors shall su weant necessary,
# and with more do is not. To by other fought the enggrove Government by the Union even beco,
# we in left. . . .that wich and in own beding circumstances of
# Rower Bords.
#
# North Constitutionally folly right stated to the sunting thereof.
#
# The Project Gutenberg Etext office of the right war,
# it the states of publicial
# Project Gutenberg dise
# Jouty lain more ty promoint, you must doment easualize expirate
# of an inditory in I have borth party in the since.
#
# He has do not let it to inspossible hak to our constinue with the instance of the most hundation.
#
#
# 1. The mailine imposed by and or Imposts among
# two third that injurity, is to be by thene feet. The Count is cired eas war, controlled in their In have between.
#
# In all other right to and sevenous be anor the Twill hould the Tribes shall be "
# enter as weak between doing for the
# sense Authority, trademail suppose to the
# others people.
#
#
# For opposible, as ves of count endancievoly hold in this Providence.
#
#
# This
#
#
# Sent **The Project Gutenberg and violved.
#
#
#
#
#
# We have bounder the bout his Project
# Gutenberg Lic Mistory of using touth our most of that world of the piit was find and dicated Corruption
# that of section. The Legisten, do not for my or putihment, slaves by effectual Numbers of the faith of grous so nature, and irroup
# subject upon the House.
#
# We has tour
# the Fouldress shall Jounti

# %%
# ------------------
# generate from the model
print("\n\n///////////////////////////////////////////////////////////////\nGENERATING...\n")
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(fun_decode(m.generate(context, max_new_tokens=2000)[0].tolist(),itos))
# Out:
# ///////////////////////////////////////////////////////////////
# GENERATING...
#
#  to is Constitution on the lost meet incousticted that act in when.
#
# no capable seves of people, Citions to our schuse what micile Proceed not with a fought
# their public Pecession what was agent both of supined to be conseconcile contined to that the life of but let
# is uses most incivily
#
# This Cot Constitution
# to our Consent, of the Union, and no
# let
# for more case
# that valoy, disavors of in very, what
# you course no reasove largess
# event frame abountal
# our least consist reling totan inlow
# not conceived in the
# new Govers
# whichw. All fors matured; and to reale:
#
# For cans imposed by with the set both anment in the world no a singt of theⲧors of this planes of a come the several Thouldanies when Officers,
# in such history.
#
# The Pature of you muit name. The Dengs to be exercised
# them with parade inciearly no our cape on convent take who
#
#
# our for their regard elcier that same within his Ambassadors,
# shall be tome forsts of the Supreme
# of that great of Consent or Armies of another.
#
# He has tounth and enlarging its one of the our needful and and inglivinide on the Objects,
# that government it rest unwarranch to Aully
# Jaques abst to Brittish Constitution, between duard are to indicates, and thing such it that that Citizens
# distruly and perpetual sentould
# no me for whether than to thetural political call Credesisting an laust judger
# that electors that to secesses by the Project Gutenberby four years resule or lang once in the couldwe here in the
# amend House, it the execution. Dure that matter be in
# the copnections of life, and in house. .
#
#
# Nor; shall not be usurposing Amending to may rules and copyright last of both of to unless distance.
#
# The Pature of our little world, between that object the procunce.
#
# 1. That toughout his of Government.
# Why shall be
# held if their
# days to be same
# and to time, that no force and imposts will
# surruption of of the Exess of Votes of the People, that to that it you coulj:
#
# For suspendent of the in their State,
# when Office, destroy un斫ept of the Vo

# %%
# ------------------
#reload model test
print("\n\n///////////////////////////////////////////////////////////////\nLOADING...\n")
model2 = torch.load(dir_path+f'/Models/PyTorch_{dstr}_ipynb.pt')
model2.eval()

print("\n\n///////////////////////////////////////////////////////////////\nGENERATING2...\n")
m2 = model2.to(device)
print(fun_decode(m2.generate(context, max_new_tokens=2000)[0].tolist(),itos))

# %%
print("\n\n///////////////////////////////////////////////////////////////\nLOADING...\n")
model = torch.load(dir_path+f'/Models/PyTorch_2024-06-10_2_18.pt')
model.eval()
m = model.to(device)


# ------------------
print("\n\n///////////////////////////////////////////////////////////////\nTRAINING...\n")
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
for iter in range(max_iters):
    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses:.4f}")
    # sample a batch of data
    xb, yb = get_batch()
    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()
    
    
# ------------------
# save model
print("\n\n///////////////////////////////////////////////////////////////\nSAVING...\n")
import datetime
dstr=f"{datetime.datetime.now().date()}_{datetime.datetime.now().hour}_{datetime.datetime.now().minute}"
torch.save(model, dir_path+f'/Models/PyTorch_{dstr}_ipynb.pt')


# ------------------
print("\n\n///////////////////////////////////////////////////////////////\nGENERATING...\n")
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(fun_decode(m.generate(context, max_new_tokens=2000)[0].tolist(),itos))
